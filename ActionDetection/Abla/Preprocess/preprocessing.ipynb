# %%
import tensorflow as tf
import pandas as pd

# %%
df_train=pd.read_csv("../archive/Train.csv")
df_train.head()
test_df = pd.read_csv("../archive/test.csv")

print(f"Total videos for training: {len(df_train)}")
print(f"Total videos for testing: {len(test_df)}")
# Out:
# Total videos for training: 50420
# Total videos for testing: 6981

# %%
#Show the distinct classes 
distinct_label=df_train["label"].unique()
distinct_label
# Out:
# array(['Doing other things', 'Pushing Two Fingers Away',
#        'Drumming Fingers', 'Sliding Two Fingers Down',
#        'Pushing Hand Away', 'Shaking Hand', 'Pulling Two Fingers In',
#        'Stop Sign', 'Zooming In With Two Fingers',
#        'Sliding Two Fingers Up', 'Zooming Out With Two Fingers',
#        'Zooming In With Full Hand', 'No gesture', 'Swiping Right',
#        'Thumb Down', 'Rolling Hand Forward', 'Pulling Hand In',
#        'Zooming Out With Full Hand', 'Swiping Left',
#        'Rolling Hand Backward', 'Turning Hand Counterclockwise',
#        'Swiping Up', 'Turning Hand Clockwise', 'Sliding Two Fingers Left',
#        'Swiping Down', 'Thumb Up', 'Sliding Two Fingers Right'],
#       dtype=object)

# %%
# Count the number of videos per class
videos_per_class = df_train['label'].value_counts()
videos_per_class
# Out:
# label
# Doing other things               4374
# Pulling Two Fingers In           1859
# Zooming Out With Two Fingers     1847
# No gesture                       1844
# Pushing Two Fingers Away         1843
# Thumb Up                         1841
# Sliding Two Fingers Down         1832
# Zooming Out With Full Hand       1832
# Pulling Hand In                  1829
# Swiping Down                     1824
# Stop Sign                        1821
# Drumming Fingers                 1818
# Sliding Two Fingers Left         1816
# Pushing Hand Away                1812
# Thumb Down                       1810
# Zooming In With Two Fingers      1801
# Zooming In With Full Hand        1799
# Shaking Hand                     1789
# Rolling Hand Forward             1788
# Sliding Two Fingers Right        1780
# Sliding Two Fingers Up           1779
# Swiping Up                       1768
# Swiping Left                     1762
# Swiping Right                    1730
# Rolling Hand Backward            1715
# Turning Hand Counterclockwise    1380
# Turning Hand Clockwise           1327
# Name: count, dtype: int64

# %%
# !pip3 install tensorflow_hub
# !pip3 install tensorflow_docs
# Out:
# Requirement already satisfied: tensorflow_hub in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_hub) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_hub) (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tf-keras>=2.14.1->tensorflow_hub) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.3.0)
# Requirement already satisfied: packaging in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.31.0)
# Requirement already satisfied: setuptools in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.48.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.36.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.35.1)
# Requirement already satisfied: rich in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (13.7.1)
# Requirement already satisfied: namex in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.0.7)
# Requirement already satisfied: optree in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.3.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras>=2.14.1->tensorflow_hub) (0.1.2)
# Requirement already satisfied: tensorflow_docs in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (2024.2.5.73858)
# Requirement already satisfied: astor in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_docs) (0.8.1)
# Requirement already satisfied: absl-py in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_docs) (1.4.0)
# Requirement already satisfied: jinja2 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_docs) (3.1.3)
# Requirement already satisfied: nbformat in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_docs) (5.9.2)
# Requirement already satisfied: protobuf>=3.12 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_docs) (3.20.3)
# Requirement already satisfied: pyyaml in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from tensorflow_docs) (6.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from jinja2->tensorflow_docs) (2.1.3)
# Requirement already satisfied: fastjsonschema in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from nbformat->tensorflow_docs) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from nbformat->tensorflow_docs) (4.19.2)
# Requirement already satisfied: jupyter-core in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from nbformat->tensorflow_docs) (5.5.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from nbformat->tensorflow_docs) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->tensorflow_docs) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->tensorflow_docs) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->tensorflow_docs) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->tensorflow_docs) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mac/miniconda3/envs/action_recognition/lib/python3.11/site-packages (from jupyter-core->nbformat->tensorflow_docs) (3.10.0)

# %%
# TensorFlow and TF-Hub modules.
from absl import logging

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow_docs.vis import embed
logging.set_verbosity(logging.ERROR)
# Some modules to help with reading the UCF101 dataset.
import random
import re
import os
import tempfile
import ssl
import cv2
import numpy as np

# Some modules to display an animation using imageio.
import imageio
from IPython import display

from urllib import request  # requires python3
from keras.applications.densenet import DenseNet121
import keras

# %%
def crop_center_square(frame):
  y, x = frame.shape[0:2]
  min_dim = min(y, x)
  start_x = (x // 2) - (min_dim // 2)
  start_y = (y // 2) - (min_dim // 2)
  return frame[start_y:start_y+min_dim,start_x:start_x+min_dim]

def load_video_from_images(folder_path, max_frames=0, resize=(224, 224)):
    frames = []
    for filename in sorted(os.listdir(folder_path)):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            frame_path = os.path.join(folder_path, filename)
            frame = cv2.imread(frame_path)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            frame = crop_center_square(frame)
            frame = cv2.resize(frame, resize)
            frames.append(frame)
            if len(frames) == max_frames:
                break
    return np.array(frames) / 255.0

def to_gif(images):
  converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
  imageio.mimsave('./animation.gif', converted_images, fps=25)
  return embed.embed_file('./animation.gif')

# %%
MAX_SEQ_LENGTH = 37
NUM_FEATURES = 1024
IMG_SIZE = 128
EPOCHS = 50

# %%
#Feature extractor using densenet
def build_feature_extractor():
    feature_extractor = DenseNet121(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.densenet.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed) 
    return keras.Model(inputs, outputs, name="feature_extractor")

# %%
# Label preprocessing with StringLookup.
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(df_train["label"]), mask_token=None
)
print(label_processor.get_vocabulary())
# Out:
# ['Doing other things', 'Drumming Fingers', 'No gesture', 'Pulling Hand In', 'Pulling Two Fingers In', 'Pushing Hand Away', 'Pushing Two Fingers Away', 'Rolling Hand Backward', 'Rolling Hand Forward', 'Shaking Hand', 'Sliding Two Fingers Down', 'Sliding Two Fingers Left', 'Sliding Two Fingers Right', 'Sliding Two Fingers Up', 'Stop Sign', 'Swiping Down', 'Swiping Left', 'Swiping Right', 'Swiping Up', 'Thumb Down', 'Thumb Up', 'Turning Hand Clockwise', 'Turning Hand Counterclockwise', 'Zooming In With Full Hand', 'Zooming In With Two Fingers', 'Zooming Out With Full Hand', 'Zooming Out With Two Fingers']

# %%
# Calculates the number of frames in each video 
def class_process(dir_path):
    if not os.path.isdir(dir_path):
        return

    for file_name in os.listdir(dir_path):
        if file_name.startswith('.'):  # Skip hidden files
            continue
        
        video_dir_path = os.path.join(dir_path, file_name)
        image_indices = []
        for image_file_name in os.listdir(video_dir_path):
            if '00' not in image_file_name:
                continue
            image_indices.append(int(image_file_name[0:4]))

        if len(image_indices) == 0:
            print('no image files', video_dir_path)
            n_frames = 0
        else:
            image_indices.sort(reverse=True)
            n_frames = len(image_indices)
            print(video_dir_path, n_frames)
        with open(os.path.join(video_dir_path, 'n_frames'), 'w') as dst_file:
            dst_file.write(str(n_frames))


dir_path = "../archive/Train/"
class_process(dir_path)
# Out:
# ../archive/Train/90107 37
# ../archive/Train/134434 37
# ../archive/Train/100601 37
# ../archive/Train/146014 37
# ../archive/Train/86062 37
# ../archive/Train/128857 37
# ../archive/Train/143566 37
# ../archive/Train/62822 37
# ../archive/Train/83510 37
# ../archive/Train/127023 37
# ../archive/Train/146828 37
# ../archive/Train/105373 37
# ../archive/Train/53759 37
# ../archive/Train/74947 37
# ../archive/Train/131146 37
# ../archive/Train/1855 37
# ../archive/Train/30805 37
# ../archive/Train/34499 37
# ../archive/Train/111541 37
# ../archive/Train/125774 37
# ../archive/Train/80395 37
# ../archive/Train/107424 37
# ../archive/Train/30039 37
# ../archive/Train/60749 37
# ../archive/Train/29928 37
# ../archive/Train/114033 37
# ../archive/Train/111773 37
# ../archive/Train/81075 37
# ../archive/Train/17429 37
# ../archive/Train/141003 37
# ../archive/Train/107616 37
# ../archive/Train/120808 37
# ../archive/Train/29326 37
# ../archive/Train/97110 37
# ../archive/Train/124494 37
# ../archive/Train/79456 37
# ../archive/Train/98964 37
# ../archive/Train/84507 37
# ../archive/Train/144571 37
# ../archive/Train/7990 37
# ../archive/Train/98158 37
# ../archive/Train/128259 37
# ../archive/Train/87382 37
# ../archive/Train/38066 37
# ../archive/Train/68716 37
# ../archive/Train/37812 37
# ../archive/Train/4729 37
# ../archive/Train/113024 37
# ../archive/Train/94795 37
# ../archive/Train/20099 37
# ../archive/Train/89218 37
# ../archive/Train/29742 37
# ../archive/Train/76846 37
# ../archive/Train/97574 37
# ../archive/Train/133047 37
# ../archive/Train/3954 37
# ../archive/Train/111317 37
# ../archive/Train/60923 37
# ../archive/Train/81411 37
# ../archive/Train/141467 37
# ../archive/Train/28690 37
# ../archive/Train/114665 37
# ../archive/Train/8580 37
# ../archive/Train/3168 37
# ../archive/Train/92006 37
# ../archive/Train/136535 37
# ../archive/Train/102700 37
# ../archive/Train/9452 37
# ../archive/Train/40518 37
# ../archive/Train/101185 37
# ../archive/Train/146642 37
# ../archive/Train/119946 37
# ../archive/Train/134262 37
# ../archive/Train/62648 37
# ../archive/Train/100057 37
# ../archive/Train/105525 37
# ../archive/Train/82294 37
# ../archive/Train/36598 37
# ../archive/Train/83346 37
# ../archive/Train/32904 37
# ../archive/Train/143330 37
# ../archive/Train/5891 37
# ../archive/Train/86406 37
# ../archive/Train/122135 37
# ../archive/Train/100265 37
# ../archive/Train/126595 37
# ../archive/Train/122909 37
# ../archive/Train/15528 37
# ../archive/Train/113672 37
# ../archive/Train/83174 37
# ../archive/Train/22198 37
# ../archive/Train/107040 37
# ../archive/Train/29570 37
# ../archive/Train/140787 37
# ../archive/Train/97746 37
# ../archive/Train/96694 37
# ../archive/Train/35913 37
# ../archive/Train/49495 37
# ../archive/Train/76248 37
# ../archive/Train/115585 37
# ../archive/Train/2288 37
# ../archive/Train/85283 37
# ../archive/Train/48547 37
# ../archive/Train/92234 37
# ../archive/Train/107286 37
# ../archive/Train/61805 37
# ../archive/Train/80537 37
# ../archive/Train/124004 37
# ../archive/Train/110231 37
# ../archive/Train/909 37
# ../archive/Train/106354 37
# ../archive/Train/28664 37
# ../archive/Train/49653 37
# ../archive/Train/137413 37
# ../archive/Train/85045 37
# ../archive/Train/121576 37
# ../archive/Train/91677 37
# ../archive/Train/118860 37
# ../archive/Train/147764 37
# ../archive/Train/69254 37
# ../archive/Train/20409 37
# ../archive/Train/33822 37
# ../archive/Train/58513 37
# ../archive/Train/89688 37
# ../archive/Train/82260 37
# ../archive/Train/24895 37
# ../archive/Train/112566 37
# ../archive/Train/130636 37
# ../archive/Train/57769 37
# ../archive/Train/117226 37
# ../archive/Train/75439 37
# ../archive/Train/87520 37
# ../archive/Train/123013 37
# ../archive/Train/90597 37
# ../archive/Train/58721 37
# ../archive/Train/94137 37
# ../archive/Train/124236 37
# ../archive/Train/140773 37
# ../archive/Train/29584 37
# ../archive/Train/133281 37
# ../archive/Train/96660 37
# ../archive/Train/64779 37
# ../archive/Train/28456 37
# ../archive/Train/78326 37
# ../archive/Train/103414 37
# ../archive/Train/120696 37
# ../archive/Train/49461 37
# ../archive/Train/9694 37
# ../archive/Train/121744 37
# ../archive/Train/85277 37
# ../archive/Train/99628 37
# ../archive/Train/145201 37
# ../archive/Train/117642 37
# ../archive/Train/39372 37
# ../archive/Train/15984 37
# ../archive/Train/123477 37
# ../archive/Train/147132 37
# ../archive/Train/88930 37
# ../archive/Train/135512 37
# ../archive/Train/86096 37
# ../archive/Train/33648 37
# ../archive/Train/75861 37
# ../archive/Train/94553 37
# ../archive/Train/63904 37
# ../archive/Train/126105 37
# ../archive/Train/95481 37
# ../archive/Train/96204 37
# ../archive/Train/106502 37
# ../archive/Train/80361 37
# ../archive/Train/72278 37
# ../archive/Train/140317 37
# ../archive/Train/22508 37
# ../archive/Train/31923 37
# ../archive/Train/2618 37
# ../archive/Train/121320 37
# ../archive/Train/54588 37
# ../archive/Train/145665 37
# ../archive/Train/46871 37
# ../archive/Train/8322 37
# ../archive/Train/73198 37
# ../archive/Train/111787 37
# ../archive/Train/99842 37
# ../archive/Train/96036 37
# ../archive/Train/106730 37
# ../archive/Train/140125 37
# ../archive/Train/80153 37
# ../archive/Train/98990 37
# ../archive/Train/12993 37
# ../archive/Train/551 37
# ../archive/Train/27248 37
# ../archive/Train/115327 37
# ../archive/Train/85421 37
# ../archive/Train/121112 37
# ../archive/Train/8110 37
# ../archive/Train/138803 37
# ../archive/Train/103242 37
# ../archive/Train/144585 37
# ../archive/Train/55668 37
# ../archive/Train/93544 37
# ../archive/Train/7964 37
# ../archive/Train/36934 37
# ../archive/Train/147300 37
# ../archive/Train/69630 37
# ../archive/Train/39140 37
# ../archive/Train/123645 37
# ../archive/Train/105989 37
# ../archive/Train/91213 37
# ../archive/Train/118438 37
# ../archive/Train/66678 37
# ../archive/Train/142672 37
# ../archive/Train/14258 37
# ../archive/Train/58177 37
# ../archive/Train/126337 37
# ../archive/Train/112102 37
# ../archive/Train/35110 37
# ../archive/Train/23075 37
# ../archive/Train/50587 37
# ../archive/Train/73705 37
# ../archive/Train/12732 37
# ../archive/Train/3365 37
# ../archive/Train/60312 37
# ../archive/Train/18208 37
# ../archive/Train/24250 37
# ../archive/Train/95812 37
# ../archive/Train/1432 37
# ../archive/Train/86439 37
# ../archive/Train/143901 37
# ../archive/Train/62445 37
# ../archive/Train/25382 37
# ../archive/Train/10859 37
# ../archive/Train/119377 37
# ../archive/Train/89471 37
# ../archive/Train/105728 37
# ../archive/Train/67137 37
# ../archive/Train/15517 37
# ../archive/Train/69891 37
# ../archive/Train/122338 37
# ../archive/Train/40527 37
# ../archive/Train/119979 37
# ../archive/Train/24062 37
# ../archive/Train/116931 37
# ../archive/Train/53130 37
# ../archive/Train/44187 37
# ../archive/Train/101986 37
# ../archive/Train/88791 37
# ../archive/Train/100854 37
# ../archive/Train/45055 37
# ../archive/Train/83379 37
# ../archive/Train/51667 37
# ../archive/Train/133078 37
# ../archive/Train/22395 37
# ../archive/Train/111328 37
# ../archive/Train/92805 37
# ../archive/Train/17072 37
# ../archive/Train/76045 37
# ../archive/Train/31782 37
# ../archive/Train/3157 37
# ../archive/Train/49698 37
# ../archive/Train/108205 37
# ../archive/Train/125921 37
# ../archive/Train/54315 37
# ../archive/Train/77197 37
# ../archive/Train/62213 37
# ../archive/Train/113827 37
# ../archive/Train/134639 37
# ../archive/Train/104890 37
# ../archive/Train/38059 37
# ../archive/Train/105942 37
# ../archive/Train/40143 37
# ../archive/Train/68729 37
# ../archive/Train/24406 37
# ../archive/Train/4716 37
# ../archive/Train/71604 37
# ../archive/Train/53554 37
# ../archive/Train/47366 37
# ../archive/Train/125579 37
# ../archive/Train/136952 37
# ../archive/Train/99889 37
# ../archive/Train/17416 37
# ../archive/Train/51203 37
# ../archive/Train/120837 37
# ../archive/Train/7193 37
# ../archive/Train/137880 37
# ../archive/Train/80198 37
# ../archive/Train/60544 37
# ../archive/Train/81876 37
# ../archive/Train/54771 37
# ../archive/Train/76421 37
# ../archive/Train/12164 37
# ../archive/Train/23411 37
# ../archive/Train/139314 37
# ../archive/Train/103887 37
# ../archive/Train/51031 37
# ../archive/Train/65204 37
# ../archive/Train/30006 37
# ../archive/Train/109581 37
# ../archive/Train/99287 37
# ../archive/Train/13284 37
# ../archive/Train/26163 37
# ../archive/Train/120239 37
# ../archive/Train/130897 37
# ../archive/Train/62021 37
# ../archive/Train/74144 37
# ../archive/Train/1056 37
# ../archive/Train/21346 37
# ../archive/Train/143559 37
# ../archive/Train/71436 37
# ../archive/Train/90904 37
# ../archive/Train/37223 37
# ../archive/Train/146817 37
# ../archive/Train/89015 37
# ../archive/Train/86861 37
# ../archive/Train/25520 37
# ../archive/Train/11715 37
# ../archive/Train/104864 37
# ../archive/Train/57100 37
# ../archive/Train/39943 37
# ../archive/Train/58148 37
# ../archive/Train/70722 37
# ../archive/Train/126308 37
# ../archive/Train/44517 37
# ../archive/Train/47392 37
# ../archive/Train/34660 37
# ../archive/Train/137874 37
# ../archive/Train/7167 37
# ../archive/Train/81882 37
# ../archive/Train/109747 37
# ../archive/Train/145468 37
# ../archive/Train/95 37
# ../archive/Train/6889 37
# ../archive/Train/43732 37
# ../archive/Train/140926 37
# ../archive/Train/55657 37
# ../archive/Train/98193 37
# ../archive/Train/61462 37
# ../archive/Train/115916 37
# ../archive/Train/50117 37
# ../archive/Train/34452 37
# ../archive/Train/73395 37
# ../archive/Train/110458 37
# ../archive/Train/46072 37
# ../archive/Train/49806 37
# ../archive/Train/22537 37
# ../archive/Train/109575 37
# ../archive/Train/13270 37
# ../archive/Train/99273 37
# ../archive/Train/55465 37
# ../archive/Train/26197 37
# ../archive/Train/61650 37
# ../archive/Train/41257 37
# ../archive/Train/130863 37
# ../archive/Train/75062 37
# ../archive/Train/11527 37
# ../archive/Train/126906 37
# ../archive/Train/33677 37
# ../archive/Train/87947 37
# ../archive/Train/52640 37
# ../archive/Train/15187 37
# ../archive/Train/147931 37
# ../archive/Train/36305 37
# ../archive/Train/91822 37
# ../archive/Train/5402 37
# ../archive/Train/44725 37
# ../archive/Train/82409 37
# ../archive/Train/20260 37
# ../archive/Train/7731 37
# ../archive/Train/138656 37
# ../archive/Train/22153 37
# ../archive/Train/28469 37
# ../archive/Train/61234 37
# ../archive/Train/76283 37
# ../archive/Train/43164 37
# ../archive/Train/85248 37
# ../archive/Train/2243 37
# ../archive/Train/77351 37
# ../archive/Train/30496 37
# ../archive/Train/109111 37
# ../archive/Train/10091 37
# ../archive/Train/82851 37
# ../archive/Train/142827 37
# ../archive/Train/41633 37
# ../archive/Train/94934 37
# ../archive/Train/25376 37
# ../archive/Train/11143 37
# ../archive/Train/89485 37
# ../archive/Train/14431 37
# ../archive/Train/52224 37
# ../archive/Train/94108 37
# ../archive/Train/69865 37
# ../archive/Train/45293 37
# ../archive/Train/33021 37
# ../archive/Train/57564 37
# ../archive/Train/91648 37
# ../archive/Train/25144 37
# ../archive/Train/11371 37
# ../archive/Train/75634 37
# ../archive/Train/142229 37
# ../archive/Train/25978 37
# ../archive/Train/88765 37
# ../archive/Train/71294 37
# ../archive/Train/66223 37
# ../archive/Train/130609 37
# ../archive/Train/52016 37
# ../archive/Train/138464 37
# ../archive/Train/93923 37
# ../archive/Train/145830 37
# ../archive/Train/34204 37
# ../archive/Train/936 37
# ../archive/Train/85846 37
# ../archive/Train/16968 37
# ../archive/Train/103619 37
# ../archive/Train/124807 37
# ../archive/Train/61006 37
# ../archive/Train/27613 37
# ../archive/Train/13426 37
# ../archive/Train/2071 37
# ../archive/Train/132962 37
# ../archive/Train/28207 37
# ../archive/Train/132502 37
# ../archive/Train/78577 37
# ../archive/Train/12994 37
# ../archive/Train/98997 37
# ../archive/Train/80154 37
# ../archive/Train/85426 37
# ../archive/Train/145450 37
# ../archive/Train/102397 37
# ../archive/Train/60588 37
# ../archive/Train/556 37
# ../archive/Train/92491 37
# ../archive/Train/99079 37
# ../archive/Train/19540 37
# ../archive/Train/72871 37
# ../archive/Train/7963 37
# ../archive/Train/144582 37
# ../archive/Train/123642 37
# ../archive/Train/117477 37
# ../archive/Train/75268 37
# ../archive/Train/69637 37
# ../archive/Train/36933 37
# ../archive/Train/112939 37
# ../archive/Train/135727 37
# ../archive/Train/101512 37
# ../archive/Train/129378 37
# ../archive/Train/104060 37
# ../archive/Train/41861 37
# ../archive/Train/94766 37
# ../archive/Train/112105 37
# ../archive/Train/57904 37
# ../archive/Train/82603 37
# ../archive/Train/126330 37
# ../archive/Train/147135 37
# ../archive/Train/88937 37
# ../archive/Train/87143 37
# ../archive/Train/128098 37
# ../archive/Train/131989 37
# ../archive/Train/135515 37
# ../archive/Train/143595 37
# ../archive/Train/104252 37
# ../archive/Train/59290 37
# ../archive/Train/52678 37
# ../archive/Train/75866 37
# ../archive/Train/129976 37
# ../archive/Train/47198 37
# ../archive/Train/27841 37
# ../archive/Train/78745 37
# ../archive/Train/132730 37
# ../archive/Train/140310 37
# ../archive/Train/110460 37
# ../archive/Train/26993 37
# ../archive/Train/80366 37
# ../archive/Train/764 37
# ../archive/Train/121327 37
# ../archive/Train/8325 37
# ../archive/Train/31118 37
# ../archive/Train/93771 37
# ../archive/Train/137242 37
# ../archive/Train/98399 37
# ../archive/Train/46876 37
# ../archive/Train/135171 37
# ../archive/Train/70970 37
# ../archive/Train/91442 37
# ../archive/Train/100296 37
# ../archive/Train/69061 37
# ../archive/Train/62489 37
# ../archive/Train/90590 37
# ../archive/Train/123014 37
# ../archive/Train/10895 37
# ../archive/Train/112753 37
# ../archive/Train/44379 37
# ../archive/Train/83187 37
# ../archive/Train/118269 37
# ../archive/Train/66029 37
# ../archive/Train/104636 37
# ../archive/Train/130403 37
# ../archive/Train/94130 37
# ../archive/Train/51499 37
# ../archive/Train/110004 37
# ../archive/Train/7709 37
# ../archive/Train/109915 37
# ../archive/Train/78321 37
# ../archive/Train/8741 37
# ../archive/Train/93315 37
# ../archive/Train/110838 37
# ../archive/Train/19316 37
# ../archive/Train/109129 37
# ../archive/Train/145206 37
# ../archive/Train/19918 37
# ../archive/Train/80530 37
# ../archive/Train/140546 37
# ../archive/Train/107281 37
# ../archive/Train/22359 37
# ../archive/Train/106353 37
# ../archive/Train/2875 37
# ../archive/Train/137414 37
# ../archive/Train/103621 37
# ../archive/Train/114696 37
# ../archive/Train/133888 37
# ../archive/Train/76089 37
# ../archive/Train/2049 37
# ../archive/Train/145034 37
# ../archive/Train/91670 37
# ../archive/Train/135343 37
# ../archive/Train/101176 37
# ../archive/Train/11349 37
# ../archive/Train/24892 37
# ../archive/Train/58514 37
# ../archive/Train/142211 37
# ../archive/Train/130631 37
# ../archive/Train/25940 37
# ../archive/Train/74518 37
# ../archive/Train/116307 37
# ../archive/Train/38637 37
# ../archive/Train/67933 37
# ../archive/Train/86401 37
# ../archive/Train/70984 37
# ../archive/Train/146477 37
# ../archive/Train/4944 37
# ../archive/Train/134057 37
# ../archive/Train/56648 37
# ../archive/Train/71856 37
# ../archive/Train/128408 37
# ../archive/Train/131525 37
# ../archive/Train/126592 37
# ../archive/Train/113675 37
# ../archive/Train/133272 37
# ../archive/Train/29577 37
# ../archive/Train/140780 37
# ../archive/Train/65658 37
# ../archive/Train/35128 37
# ../archive/Train/47508 37
# ../archive/Train/81624 37
# ../archive/Train/125317 37
# ../archive/Train/54923 37
# ../archive/Train/17278 37
# ../archive/Train/96693 37
# ../archive/Train/114450 37
# ../archive/Train/84356 37
# ../archive/Train/49492 37
# ../archive/Train/120665 37
# ../archive/Train/98709 37
# ../archive/Train/144320 37
# ../archive/Train/23871 37
# ../archive/Train/115582 37
# ../archive/Train/9667 37
# ../archive/Train/79035 37
# ../archive/Train/97573 37
# ../archive/Train/3953 37
# ../archive/Train/107275 37
# ../archive/Train/29745 37
# ../archive/Train/141460 37
# ../archive/Train/79809 37
# ../archive/Train/144112 37
# ../archive/Train/114662 37
# ../archive/Train/8587 37
# ../archive/Train/42248 37
# ../archive/Train/84164 37
# ../archive/Train/121585 37
# ../archive/Train/48772 37
# ../archive/Train/17876 37
# ../archive/Train/30668 37
# ../archive/Train/136532 37
# ../archive/Train/92001 37
# ../archive/Train/68375 37
# ../archive/Train/116135 37
# ../archive/Train/53934 37
# ../archive/Train/122300 37
# ../archive/Train/100050 37
# ../archive/Train/134265 37
# ../archive/Train/105522 37
# ../archive/Train/143337 37
# ../archive/Train/32903 37
# ../archive/Train/83341 37
# ../archive/Train/113447 37
# ../archive/Train/71258 37
# ../archive/Train/141004 37
# ../archive/Train/125541 37
# ../archive/Train/79451 37
# ../archive/Train/133424 37
# ../archive/Train/97117 37
# ../archive/Train/136156 37
# ../archive/Train/54749 37
# ../archive/Train/59 37
# ../archive/Train/72885 37
# ../archive/Train/137084 37
# ../archive/Train/76419 37
# ../archive/Train/87385 37
# ../archive/Train/134601 37
# ../archive/Train/37815 37
# ../archive/Train/38061 37
# ../archive/Train/86257 37
# ../archive/Train/143753 37
# ../archive/Train/59056 37
# ../archive/Train/15379 37
# ../archive/Train/113023 37
# ../archive/Train/56822 37
# ../archive/Train/131373 37
# ../archive/Train/67759 37
# ../archive/Train/62019 37
# ../archive/Train/32769 37
# ../archive/Train/116763 37
# ../archive/Train/40349 37
# ../archive/Train/10439 37
# ../archive/Train/113211 37
# ../archive/Train/74940 37
# ../archive/Train/111546 37
# ../archive/Train/23429 37
# ../archive/Train/141236 37
# ../archive/Train/30802 37
# ../archive/Train/51009 37
# ../archive/Train/133616 37
# ../archive/Train/7399 37
# ../archive/Train/80392 37
# ../archive/Train/102151 37
# ../archive/Train/48124 37
# ../archive/Train/114034 37
# ../archive/Train/51835 37
# ../archive/Train/120201 37
# ../archive/Train/101149 37
# ../archive/Train/24091 37
# ../archive/Train/57563 37
# ../archive/Train/70341 37
# ../archive/Train/20431 37
# ../archive/Train/66224 37
# ../archive/Train/118064 37
# ../archive/Train/88762 37
# ../archive/Train/93924 37
# ../archive/Train/22366 37
# ../archive/Train/50746 37
# ../archive/Train/77958 37
# ../archive/Train/85841 37
# ../archive/Train/145837 37
# ../archive/Train/61001 37
# ../archive/Train/124800 37
# ../archive/Train/93118 37
# ../archive/Train/42283 37
# ../archive/Train/43351 37
# ../archive/Train/65693 37
# ../archive/Train/7736 37
# ../archive/Train/34031 37
# ../archive/Train/96658 37
# ../archive/Train/64741 37
# ../archive/Train/49459 37
# ../archive/Train/22968 37
# ../archive/Train/3396 37
# ../archive/Train/31543 37
# ../archive/Train/76284 37
# ../archive/Train/137619 37
# ../archive/Train/99610 37
# ../archive/Train/13613 37
# ../archive/Train/109116 37
# ../archive/Train/2244 37
# ../archive/Train/77356 37
# ../archive/Train/43163 37
# ../archive/Train/106962 37
# ../archive/Train/10096 37
# ../archive/Train/11144 37
# ../archive/Train/56683 37
# ../archive/Train/25371 37
# ../archive/Train/83984 37
# ../archive/Train/41634 37
# ../archive/Train/87518 37
# ../archive/Train/44346 37
# ../archive/Train/70173 37
# ../archive/Train/135972 37
# ../archive/Train/104609 37
# ../archive/Train/123817 37
# ../archive/Train/34455 37
# ../archive/Train/73392 37
# ../archive/Train/115911 37
# ../archive/Train/80359 37
# ../archive/Train/35587 37
# ../archive/Train/60785 37
# ../archive/Train/27042 37
# ../archive/Train/2620 37
# ../archive/Train/31127 37
# ../archive/Train/61657 37
# ../archive/Train/11520 37
# ../archive/Train/88908 37
# ../archive/Train/130864 37
# ../archive/Train/38298 37
# ../archive/Train/118632 37
# ../archive/Train/88134 37
# ../archive/Train/130058 37
# ../archive/Train/15180 37
# ../archive/Train/66472 37
# ../archive/Train/142478 37
# ../archive/Train/20267 37
# ../archive/Train/86892 37
# ../archive/Train/1899 37
# ../archive/Train/14052 37
# ../archive/Train/117448 37
# ../archive/Train/39178 37
# ../archive/Train/128295 37
# ../archive/Train/41062 37
# ../archive/Train/104863 37
# ../archive/Train/25527 37
# ../archive/Train/20869 37
# ../archive/Train/1297 37
# ../archive/Train/33442 37
# ../archive/Train/52475 37
# ../archive/Train/39944 37
# ../archive/Train/36130 37
# ../archive/Train/67792 37
# ../archive/Train/106708 37
# ../archive/Train/47395 37
# ../archive/Train/72072 37
# ../archive/Train/138007 37
# ../archive/Train/96832 37
# ../archive/Train/85419 37
# ../archive/Train/13045 37
# ../archive/Train/92 37
# ../archive/Train/81885 37
# ../archive/Train/55650 37
# ../archive/Train/140921 37
# ../archive/Train/8128 37
# ../archive/Train/111579 37
# ../archive/Train/47153 37
# ../archive/Train/139313 37
# ../archive/Train/17623 37
# ../archive/Train/65203 37
# ../archive/Train/51036 37
# ../archive/Train/114837 37
# ../archive/Train/133629 37
# ../archive/Train/103880 37
# ../archive/Train/46081 37
# ../archive/Train/99280 37
# ../archive/Train/30001 37
# ../archive/Train/29910 37
# ../archive/Train/26164 37
# ../archive/Train/56213 37
# ../archive/Train/62026 37
# ../archive/Train/127827 37
# ../archive/Train/15948 37
# ../archive/Train/128053 37
# ../archive/Train/129181 37
# ../archive/Train/33684 37
# ../archive/Train/74143 37
# ../archive/Train/1051 37
# ../archive/Train/10406 37
# ../archive/Train/90903 37
# ../archive/Train/45604 37
# ../archive/Train/15174 37
# ../archive/Train/21341 37
# ../archive/Train/89012 37
# ../archive/Train/32564 37
# ../archive/Train/59855 37
# ../archive/Train/56021 37
# ../archive/Train/24401 37
# ../archive/Train/40144 37
# ../archive/Train/86268 37
# ../archive/Train/58987 37
# ../archive/Train/71603 37
# ../archive/Train/127229 37
# ../archive/Train/89220 37
# ../archive/Train/119526 37
# ../archive/Train/53553 37
# ../archive/Train/14294 37
# ../archive/Train/6046 37
# ../archive/Train/136955 37
# ../archive/Train/7194 37
# ../archive/Train/110699 37
# ../archive/Train/137887 37
# ../archive/Train/35741 37
# ../archive/Train/51204 37
# ../archive/Train/97128 37
# ../archive/Train/54776 37
# ../archive/Train/66 37
# ../archive/Train/60543 37
# ../archive/Train/61491 37
# ../archive/Train/114239 37
# ../archive/Train/24065 37
# ../archive/Train/135388 37
# ../archive/Train/10250 37
# ../archive/Train/1607 37
# ../archive/Train/32100 37
# ../archive/Train/90769 37
# ../archive/Train/11382 37
# ../archive/Train/89644 37
# ../archive/Train/44180 37
# ../archive/Train/24859 37
# ../archive/Train/119142 37
# ../archive/Train/37472 37
# ../archive/Train/53137 37
# ../archive/Train/15722 37
# ../archive/Train/21517 37
# ../archive/Train/118090 37
# ../archive/Train/88796 37
# ../archive/Train/144911 37
# ../archive/Train/65455 37
# ../archive/Train/51660 37
# ../archive/Train/17075 37
# ../archive/Train/64587 37
# ../archive/Train/23240 37
# ../archive/Train/81429 37
# ../archive/Train/26732 37
# ../archive/Train/79836 37
# ../archive/Train/31785 37
# ../archive/Train/3150 37
# ../archive/Train/132991 37
# ../archive/Train/17849 37
# ../archive/Train/29548 37
# ../archive/Train/50580 37
# ../archive/Train/139777 37
# ../archive/Train/108030 37
# ../archive/Train/98736 37
# ../archive/Train/12735 37
# ../archive/Train/54120 37
# ../archive/Train/111921 37
# ../archive/Train/40712 37
# ../archive/Train/68178 37
# ../archive/Train/10062 37
# ../archive/Train/128437 37
# ../archive/Train/143906 37
# ../archive/Train/67130 37
# ../archive/Train/122931 37
# ../archive/Train/53305 37
# ../archive/Train/68944 37
# ../archive/Train/112798 37
# ../archive/Train/71055 37
# ../archive/Train/134854 37
# ../archive/Train/45260 37
# ../archive/Train/106157 37
# ../archive/Train/132362 37
# ../archive/Train/96651 37
# ../archive/Train/138658 37
# ../archive/Train/140742 37
# ../archive/Train/110032 37
# ../archive/Train/145230 37
# ../archive/Train/336 37
# ../archive/Train/121775 37
# ../archive/Train/48582 37
# ../archive/Train/8777 37
# ../archive/Train/114492 37
# ../archive/Train/93323 37
# ../archive/Train/87511 37
# ../archive/Train/39727 37
# ../archive/Train/5854 37
# ../archive/Train/82063 37
# ../archive/Train/126550 37
# ../archive/Train/52824 37
# ../archive/Train/117025 37
# ../archive/Train/69265 37
# ../archive/Train/45893 37
# ../archive/Train/90794 37
# ../archive/Train/91646 37
# ../archive/Train/119983 37
# ../archive/Train/24098 37
# ../archive/Train/101140 37
# ../archive/Train/130607 37
# ../archive/Train/94334 37
# ../archive/Train/25976 37
# ../archive/Train/126762 37
# ../archive/Train/82251 37
# ../archive/Train/85848 37
# ../archive/Train/17088 37
# ../archive/Train/132150 37
# ../archive/Train/29787 37
# ../archive/Train/43358 37
# ../archive/Train/121547 37
# ../archive/Train/145002 37
# ../archive/Train/13428 37
# ../archive/Train/104 37
# ../archive/Train/19112 37
# ../archive/Train/61008 37
# ../archive/Train/8545 37
# ../archive/Train/120495 37
# ../archive/Train/20860 37
# ../archive/Train/87347 37
# ../archive/Train/69601 37
# ../archive/Train/126306 37
# ../archive/Train/82635 37
# ../archive/Train/142643 37
# ../archive/Train/130263 37
# ../archive/Train/94750 37
# ../archive/Train/79493 37
# ../archive/Train/132534 37
# ../archive/Train/13870 37
# ../archive/Train/93575 37
# ../archive/Train/7955 37
# ../archive/Train/8121 37
# ../archive/Train/138832 37
# ../archive/Train/64922 37
# ../archive/Train/121123 37
# ../archive/Train/115316 37
# ../archive/Train/109749 37
# ../archive/Train/6887 37
# ../archive/Train/31912 37
# ../archive/Train/140326 37
# ../archive/Train/49808 37
# ../archive/Train/22539 37
# ../archive/Train/72249 37
# ../archive/Train/124663 37
# ../archive/Train/81282 37
# ../archive/Train/111584 37
# ../archive/Train/106533 37
# ../archive/Train/115918 37
# ../archive/Train/132706 37
# ../archive/Train/137274 37
# ../archive/Train/19744 37
# ../archive/Train/46840 37
# ../archive/Train/2629 37
# ../archive/Train/50925 37
# ../archive/Train/33679 37
# ../archive/Train/122594 37
# ../archive/Train/63109 37
# ../archive/Train/11529 37
# ../archive/Train/41259 37
# ../archive/Train/123446 37
# ../archive/Train/117673 37
# ../archive/Train/39343 37
# ../archive/Train/58374 37
# ../archive/Train/129940 37
# ../archive/Train/112301 37
# ../archive/Train/82407 37
# ../archive/Train/104264 37
# ../archive/Train/87949 37
# ../archive/Train/37823 37
# ../archive/Train/116567 37
# ../archive/Train/38057 37
# ../archive/Train/20894 37
# ../archive/Train/113829 37
# ../archive/Train/95676 37
# ../archive/Train/59060 37
# ../archive/Train/83713 37
# ../archive/Train/56814 37
# ../archive/Train/80196 37
# ../archive/Train/65038 37
# ../archive/Train/17418 37
# ../archive/Train/47368 37
# ../archive/Train/19582 37
# ../archive/Train/93581 37
# ../archive/Train/144540 37
# ../archive/Train/65804 37
# ../archive/Train/9007 37
# ../archive/Train/145492 37
# ../archive/Train/81878 37
# ../archive/Train/92453 37
# ../archive/Train/136160 37
# ../archive/Train/18450 37
# ../archive/Train/79655 37
# ../archive/Train/103889 37
# ../archive/Train/125745 37
# ../archive/Train/111570 37
# ../archive/Train/30834 37
# ../archive/Train/120237 37
# ../archive/Train/84704 37
# ../archive/Train/137280 37
# ../archive/Train/47966 37
# ../archive/Train/99289 37
# ../archive/Train/18662 37
# ../archive/Train/92661 37
# ../archive/Train/30008 37
# ../archive/Train/9235 37
# ../archive/Train/116755 37
# ../archive/Train/86053 37
# ../archive/Train/146025 37
# ../archive/Train/134405 37
# ../archive/Train/15941 37
# ../archive/Train/53768 37
# ../archive/Train/146819 37
# ../archive/Train/83521 37
# ../archive/Train/127012 37
# ../archive/Train/113227 37
# ../archive/Train/21348 37
# ../archive/Train/143557 37
# ../archive/Train/104290 37
# ../archive/Train/59252 37
# ../archive/Train/54915 37
# ../archive/Train/111114 37
# ../archive/Train/28493 37
# ../archive/Train/42870 37
# ../archive/Train/107071 37
# ../archive/Train/18206 37
# ../archive/Train/54129 37
# ../archive/Train/48576 37
# ../archive/Train/121781 37
# ../archive/Train/26509 37
# ../archive/Train/90552 37
# ../archive/Train/116331 37
# ../archive/Train/38601 37
# ../archive/Train/91480 37
# ../archive/Train/63599 37
# ../archive/Train/68171 37
# ../archive/Train/83145 37
# ../archive/Train/127476 37
# ../archive/Train/143133 37
# ../archive/Train/122938 37
# ../archive/Train/67139 37
# ../archive/Train/119379 37
# ../archive/Train/112791 37
# ../archive/Train/45867 37
# ../archive/Train/62679 37
# ../archive/Train/69291 37
# ../archive/Train/119977 37
# ../archive/Train/146673 37
# ../archive/Train/53902 37
# ../archive/Train/59404 37
# ../archive/Train/25982 37
# ../archive/Train/96497 37
# ../archive/Train/18808 37
# ../archive/Train/73539 37
# ../archive/Train/51669 37
# ../archive/Train/76877 37
# ../archive/Train/3965 37
# ../archive/Train/48744 37
# ../archive/Train/9463 37
# ../archive/Train/92037 37
# ../archive/Train/18034 37
# ../archive/Train/144124 37
# ../archive/Train/84152 37
# ../archive/Train/1093 37
# ../archive/Train/14858 37
# ../archive/Train/33646 37
# ../archive/Train/74181 37
# ../archive/Train/101729 37
# ../archive/Train/126937 37
# ../archive/Train/57303 37
# ../archive/Train/11516 37
# ../archive/Train/41266 37
# ../archive/Train/91813 37
# ../archive/Train/52671 37
# ../archive/Train/140319 37
# ../archive/Train/103842 37
# ../archive/Train/72276 37
# ../archive/Train/110469 37
# ../archive/Train/34463 37
# ../archive/Train/50126 37
# ../archive/Train/64313 37
# ../archive/Train/31111 37
# ../archive/Train/108496 37
# ../archive/Train/98390 37
# ../archive/Train/54586 37
# ../archive/Train/99242 37
# ../archive/Train/136399 37
# ../archive/Train/2616 37
# ../archive/Train/77704 37
# ../archive/Train/43531 37
# ../archive/Train/46271 37
# ../archive/Train/72044 37
# ../archive/Train/7156 37
# ../archive/Train/8922 37
# ../archive/Train/138031 37
# ../archive/Train/34651 37
# ../archive/Train/61453 37
# ../archive/Train/26394 37
# ../archive/Train/72878 37
# ../archive/Train/140917 37
# ../archive/Train/49239 37
# ../archive/Train/31323 37
# ../archive/Train/115329 37
# ../archive/Train/43703 37
# ../archive/Train/92498 37
# ../archive/Train/129371 37
# ../archive/Train/105987 37
# ../archive/Train/75261 37
# ../archive/Train/104855 37
# ../archive/Train/70713 37
# ../archive/Train/20063 37
# ../archive/Train/14256 37
# ../archive/Train/58179 37
# ../archive/Train/41868 37
# ../archive/Train/66676 37
# ../archive/Train/104069 37
# ../archive/Train/88330 37
# ../archive/Train/139587 37
# ../archive/Train/34235 37
# ../archive/Train/907 37
# ../archive/Train/145801 37
# ../archive/Train/22350 37
# ../archive/Train/43367 37
# ../archive/Train/121578 37
# ../archive/Train/13417 37
# ../archive/Train/109312 37
# ../archive/Train/27622 37
# ../archive/Train/103628 37
# ../archive/Train/3192 37
# ../archive/Train/31747 37
# ../archive/Train/133881 37
# ../archive/Train/91679 37
# ../archive/Train/129715 37
# ../archive/Train/33010 37
# ../archive/Train/66212 37
# ../archive/Train/118052 37
# ../archive/Train/25949 37
# ../archive/Train/88754 37
# ../archive/Train/100891 37
# ../archive/Train/101943 37
# ../archive/Train/44142 37
# ../archive/Train/14632 37
# ../archive/Train/90599 37
# ../archive/Train/11172 37
# ../archive/Train/62480 37
# ../archive/Train/75437 37
# ../archive/Train/142816 37
# ../archive/Train/129527 37
# ../archive/Train/24295 37
# ../archive/Train/57767 37
# ../archive/Train/118260 37
# ../archive/Train/113688 37
# ../archive/Train/134896 37
# ../archive/Train/69854 37
# ../archive/Train/52215 37
# ../archive/Train/20635 37
# ../archive/Train/44370 37
# ../archive/Train/135944 37
# ../archive/Train/37682 37
# ../archive/Train/78328 37
# ../archive/Train/17285 37
# ../archive/Train/64777 37
# ../archive/Train/28458 37
# ../archive/Train/51490 37
# ../archive/Train/72612 37
# ../archive/Train/99626 37
# ../archive/Train/27410 37
# ../archive/Train/2272 37
# ../archive/Train/8748 37
# ../archive/Train/31575 37
# ../archive/Train/50784 37
# ../archive/Train/2888 37
# ../archive/Train/23276 37
# ../archive/Train/85883 37
# ../archive/Train/111319 37
# ../archive/Train/35313 37
# ../archive/Train/51656 37
# ../archive/Train/16191 37
# ../archive/Train/92008 37
# ../archive/Train/108234 37
# ../archive/Train/26704 37
# ../archive/Train/79800 37
# ../archive/Train/128633 37
# ../archive/Train/56473 37
# ../archive/Train/25181 37
# ../archive/Train/62646 37
# ../archive/Train/63794 37
# ../archive/Train/10266 37
# ../archive/Train/119948 37
# ../archive/Train/67334 37
# ../archive/Train/83946 37
# ../archive/Train/40724 37
# ../archive/Train/95823 37
# ../archive/Train/1403 37
# ../archive/Train/24261 37
# ../archive/Train/4171 37
# ../archive/Train/134862 37
# ../archive/Train/118294 37
# ../archive/Train/127449 37
# ../archive/Train/88592 37
# ../archive/Train/59609 37
# ../archive/Train/119346 37
# ../archive/Train/73734 37
# ../archive/Train/139741 37
# ../archive/Train/51464 37
# ../archive/Train/136709 37
# ../archive/Train/60323 37
# ../archive/Train/77394 37
# ../archive/Train/48549 37
# ../archive/Train/42073 37
# ../archive/Train/114459 37
# ../archive/Train/108006 37
# ../archive/Train/98700 37
# ../archive/Train/1067 37
# ../archive/Train/24605 37
# ../archive/Train/10430 37
# ../archive/Train/90109 37
# ../archive/Train/39388 37
# ../archive/Train/128065 37
# ../archive/Train/53757 37
# ../archive/Train/74949 37
# ../archive/Train/4515 37
# ../archive/Train/21377 37
# ../archive/Train/143568 37
# ../archive/Train/34497 37
# ../archive/Train/23420 37
# ../archive/Train/120208 37
# ../archive/Train/42417 37
# ../archive/Train/61695 37
# ../archive/Train/12367 37
# ../archive/Train/799 37
# ../archive/Train/102158 37
# ../archive/Train/46285 37
# ../archive/Train/79458 37
# ../archive/Train/107618 37
# ../archive/Train/120806 37
# ../archive/Train/65007 37
# ../archive/Train/9804 37
# ../archive/Train/6070 37
# ../archive/Train/47357 37
# ../archive/Train/55692 37
# ../archive/Train/42625 37
# ../archive/Train/50 37
# ../archive/Train/146228 37
# ../archive/Train/10602 37
# ../archive/Train/59863 37
# ../archive/Train/75295 37
# ../archive/Train/21979 37
# ../archive/Train/113816 37
# ../archive/Train/134608 37
# ../archive/Train/56017 37
# ../archive/Train/62222 37
# ../archive/Train/119510 37
# ../archive/Train/20097 37
# ../archive/Train/90767 37
# ../archive/Train/116104 37
# ../archive/Train/38434 37
# ../archive/Train/146674 37
# ../archive/Train/57599 37
# ../archive/Train/21519 37
# ../archive/Train/53139 37
# ../archive/Train/95215 37
# ../archive/Train/116938 37
# ../archive/Train/111321 37
# ../archive/Train/125114 37
# ../archive/Train/81427 37
# ../archive/Train/106396 37
# ../archive/Train/84969 37
# ../archive/Train/76870 37
# ../archive/Train/92030 37
# ../archive/Train/102736 37
# ../archive/Train/85087 37
# ../archive/Train/120466 37
# ../archive/Train/84155 37
# ../archive/Train/79838 37
# ../archive/Train/139779 37
# ../archive/Train/28494 37
# ../archive/Train/111113 37
# ../archive/Train/81615 37
# ../archive/Train/125326 37
# ../archive/Train/35119 37
# ../archive/Train/79236 37
# ../archive/Train/107076 37
# ../archive/Train/42877 37
# ../archive/Train/65669 37
# ../archive/Train/97770 37
# ../archive/Train/23840 37
# ../archive/Train/43199 37
# ../archive/Train/136731 37
# ../archive/Train/18201 37
# ../archive/Train/144311 37
# ../archive/Train/98738 37
# ../archive/Train/35925 37
# ../archive/Train/90555 37
# ../archive/Train/100253 37
# ../archive/Train/147594 37
# ../archive/Train/68176 37
# ../archive/Train/24259 37
# ../archive/Train/86430 37
# ../archive/Train/38606 37
# ../archive/Train/4149 37
# ../archive/Train/113644 37
# ../archive/Train/83142 37
# ../archive/Train/112796 37
# ../archive/Train/135988 37
# ../archive/Train/70189 37
# ../archive/Train/131514 37
# ../archive/Train/107412 37
# ../archive/Train/29122 37
# ../archive/Train/97314 37
# ../archive/Train/114839 37
# ../archive/Train/133627 37
# ../archive/Train/81271 37
# ../archive/Train/84703 37
# ../archive/Train/120230 37
# ../archive/Train/51804 37
# ../archive/Train/92666 37
# ../archive/Train/102160 37
# ../archive/Train/32758 37
# ../archive/Train/87186 37
# ../archive/Train/90131 37
# ../archive/Train/100637 37
# ../archive/Train/128861 37
# ../archive/Train/66488 37
# ../archive/Train/113220 37
# ../archive/Train/83526 37
# ../archive/Train/122755 37
# ../archive/Train/116560 37
# ../archive/Train/68720 37
# ../archive/Train/39182 37
# ../archive/Train/67768 37
# ../archive/Train/59067 37
# ../archive/Train/130290 37
# ../archive/Train/15348 37
# ../archive/Train/29310 37
# ../archive/Train/97126 37
# ../archive/Train/80191 37
# ../archive/Train/79460 37
# ../archive/Train/110697 37
# ../archive/Train/12951 37
# ../archive/Train/72088 37
# ../archive/Train/6048 37
# ../archive/Train/125570 37
# ../archive/Train/114237 37
# ../archive/Train/108668 37
# ../archive/Train/93586 37
# ../archive/Train/136167 37
# ../archive/Train/54778 37
# ../archive/Train/73966 37
# ../archive/Train/145495 37
# ../archive/Train/139913 37
# ../archive/Train/48327 37
# ../archive/Train/80357 37
# ../archive/Train/35589 37
# ../archive/Train/140321 37
# ../archive/Train/31915 37
# ../archive/Train/96232 37
# ../archive/Train/106534 37
# ../archive/Train/144781 37
# ../archive/Train/103046 37
# ../archive/Train/61659 37
# ../archive/Train/50922 37
# ../archive/Train/43509 37
# ../archive/Train/85625 37
# ../archive/Train/755 37
# ../archive/Train/92692 37
# ../archive/Train/102194 37
# ../archive/Train/101711 37
# ../archive/Train/91017 37
# ../archive/Train/14860 37
# ../archive/Train/123441 37
# ../archive/Train/147104 37
# ../archive/Train/69434 37
# ../archive/Train/88906 37
# ../archive/Train/129947 37
# ../archive/Train/130056 37
# ../archive/Train/52649 37
# ../archive/Train/94565 37
# ../archive/Train/129349 37
# ../archive/Train/25529 37
# ../archive/Train/147336 37
# ../archive/Train/69606 37
# ../archive/Train/39176 37
# ../archive/Train/75259 37
# ../archive/Train/87340 37
# ../archive/Train/58141 37
# ../archive/Train/82632 37
# ../archive/Train/126301 37
# ../archive/Train/112134 37
# ../archive/Train/88308 37
# ../archive/Train/59093 37
# ../archive/Train/140113 37
# ../archive/Train/138009 37
# ../archive/Train/78546 37
# ../archive/Train/125584 37
# ../archive/Train/132533 37
# ../archive/Train/96000 37
# ../archive/Train/106706 37
# ../archive/Train/28236 37
# ../archive/Train/8126 37
# ../archive/Train/138835 37
# ../archive/Train/103274 37
# ../archive/Train/73992 37
# ../archive/Train/115311 37
# ../archive/Train/45894 37
# ../archive/Train/39512 37
# ../archive/Train/33028 37
# ../archive/Train/146680 37
# ../archive/Train/37488 37
# ../archive/Train/78122 37
# ../archive/Train/50748 37
# ../archive/Train/77956 37
# ../archive/Train/96464 37
# ../archive/Train/106362 37
# ../archive/Train/29780 37
# ../archive/Train/140577 37
# ../archive/Train/22368 37
# ../archive/Train/103 37
# ../archive/Train/145005 37
# ../archive/Train/103610 37
# ../archive/Train/96656 37
# ../archive/Train/106150 37
# ../archive/Train/28460 37
# ../archive/Train/23088 37
# ../archive/Train/43951 37
# ../archive/Train/78310 37
# ../archive/Train/80733 37
# ../archive/Train/7738 37
# ../archive/Train/42883 37
# ../archive/Train/115547 37
# ../archive/Train/85241 37
# ../archive/Train/121772 37
# ../archive/Train/48585 37
# ../archive/Train/331 37
# ../archive/Train/27428 37
# ../archive/Train/145237 37
# ../archive/Train/93324 37
# ../archive/Train/110809 37
# ../archive/Train/3398 37
# ../archive/Train/8770 37
# ../archive/Train/114495 37
# ../archive/Train/117210 37
# ../archive/Train/134092 37
# ../archive/Train/82858 37
# ../archive/Train/101375 37
# ../archive/Train/68182 37
# ../archive/Train/70941 37
# ../archive/Train/10098 37
# ../archive/Train/5853 37
# ../archive/Train/130432 37
# ../archive/Train/94101 37
# ../archive/Train/104607 37
# ../archive/Train/123819 37
# ../archive/Train/118258 37
# ../archive/Train/82064 37
# ../archive/Train/14438 37
# ../archive/Train/46282 37
# ../archive/Train/23615 37
# ../archive/Train/17420 37
# ../archive/Train/9803 37
# ../archive/Train/108657 37
# ../archive/Train/60572 37
# ../archive/Train/109785 37
# ../archive/Train/18468 37
# ../archive/Train/54747 37
# ../archive/Train/48318 37
# ../archive/Train/30202 37
# ../archive/Train/74340 37
# ../archive/Train/40175 37
# ../archive/Train/105974 37
# ../archive/Train/10605 37
# ../archive/Train/113811 37
# ../archive/Train/32555 37
# ../archive/Train/75292 37
# ../archive/Train/59864 37
# ../archive/Train/53562 37
# ../archive/Train/20090 37
# ../archive/Train/4720 37
# ../archive/Train/71632 37
# ../archive/Train/66685 37
# ../archive/Train/21142 37
# ../archive/Train/39981 37
# ../archive/Train/74172 37
# ../archive/Train/122558 37
# ../archive/Train/62017 37
# ../archive/Train/100608 37
# ../archive/Train/56222 37
# ../archive/Train/119725 37
# ../archive/Train/146821 37
# ../archive/Train/53750 37
# ../archive/Train/67565 37
# ../archive/Train/21370 37
# ../archive/Train/52682 37
# ../archive/Train/71400 37
# ../archive/Train/90932 37
# ../archive/Train/7397 37
# ../archive/Train/72285 37
# ../archive/Train/26969 37
# ../archive/Train/51007 37
# ../archive/Train/114806 37
# ../archive/Train/139322 37
# ../archive/Train/17612 37
# ../archive/Train/47162 37
# ../archive/Train/108465 37
# ../archive/Train/26155 37
# ../archive/Train/61692 37
# ../archive/Train/3737 37
# ../archive/Train/42410 37
# ../archive/Train/30030 37
# ../archive/Train/27087 37
# ../archive/Train/92659 37
# ../archive/Train/11181 37
# ../archive/Train/82893 37
# ../archive/Train/74516 37
# ../archive/Train/116309 37
# ../archive/Train/45251 37
# ../archive/Train/118293 37
# ../archive/Train/37671 37
# ../archive/Train/67101 37
# ../archive/Train/35126 37
# ../archive/Train/79209 37
# ../archive/Train/51463 37
# ../archive/Train/77393 37
# ../archive/Train/2281 37
# ../archive/Train/54111 37
# ../archive/Train/98707 37
# ../archive/Train/108001 37
# ../archive/Train/26531 37
# ../archive/Train/31586 37
# ../archive/Train/3353 37
# ../archive/Train/81418 37
# ../archive/Train/6413 37
# ../archive/Train/73501 37
# ../archive/Train/28699 37
# ../archive/Train/23271 37
# ../archive/Train/50783 37
# ../archive/Train/51651 37
# ../archive/Train/84956 37
# ../archive/Train/60116 37
# ../archive/Train/3161 37
# ../archive/Train/42246 37
# ../archive/Train/12536 37
# ../archive/Train/25186 37
# ../archive/Train/56474 37
# ../archive/Train/90758 37
# ../archive/Train/128634 37
# ../archive/Train/74724 37
# ../archive/Train/1636 37
# ../archive/Train/40511 37
# ../archive/Train/10261 37
# ../archive/Train/21526 37
# ../archive/Train/143339 37
# ../archive/Train/116907 37
# ../archive/Train/5296 37
# ../archive/Train/119173 37
# ../archive/Train/37443 37
# ../archive/Train/62487 37
# ../archive/Train/25340 37
# ../archive/Train/129520 37
# ../archive/Train/66027 37
# ../archive/Train/118267 37
# ../archive/Train/11949 37
# ../archive/Train/36757 37
# ../archive/Train/71090 37
# ../archive/Train/5050 37
# ../archive/Train/58728 37
# ../archive/Train/64770 37
# ../archive/Train/34000 37
# ../archive/Train/133288 37
# ../archive/Train/138660 37
# ../archive/Train/51497 37
# ../archive/Train/43152 37
# ../archive/Train/106953 37
# ../archive/Train/115578 37
# ../archive/Train/13622 37
# ../archive/Train/110836 37
# ../archive/Train/31572 37
# ../archive/Train/145806 37
# ../archive/Train/77969 37
# ../archive/Train/16162 37
# ../archive/Train/97589 37
# ../archive/Train/140548 37
# ../archive/Train/72427 37
# ../archive/Train/93915 37
# ../archive/Train/110238 37
# ../archive/Train/109315 37
# ../archive/Train/99413 37
# ../archive/Train/43360 37
# ../archive/Train/77155 37
# ../archive/Train/114698 37
# ../archive/Train/133886 37
# ../archive/Train/31740 37
# ../archive/Train/61030 37
# ../archive/Train/56480 37
# ../archive/Train/11347 37
# ../archive/Train/118869 37
# ../archive/Train/75602 37
# ../archive/Train/129712 37
# ../archive/Train/10295 37
# ../archive/Train/101178 37
# ../archive/Train/88753 37
# ../archive/Train/100896 37
# ../archive/Train/45097 37
# ../archive/Train/36565 37
# ../archive/Train/20400 37
# ../archive/Train/70370 37
# ../archive/Train/119187 37
# ../archive/Train/5262 37
# ../archive/Train/8925 37
# ../archive/Train/16506 37
# ../archive/Train/22733 37
# ../archive/Train/35784 37
# ../archive/Train/137842 37
# ../archive/Train/73191 37
# ../archive/Train/6083 37
# ../archive/Train/106739 37
# ../archive/Train/28209 37
# ../archive/Train/50313 37
# ../archive/Train/55661 37
# ../archive/Train/109771 37
# ../archive/Train/99077 37
# ../archive/Train/2423 37
# ../archive/Train/57136 37
# ../archive/Train/25516 37
# ../archive/Train/147309 37
# ../archive/Train/75266 37
# ../archive/Train/44521 37
# ../archive/Train/118431 37
# ../archive/Train/36101 37
# ../archive/Train/15383 37
# ../archive/Train/39975 37
# ../archive/Train/57304 37
# ../archive/Train/91028 37
# ../archive/Train/126930 37
# ../archive/Train/116799 37
# ../archive/Train/129144 37
# ../archive/Train/41261 37
# ../archive/Train/128096 37
# ../archive/Train/75054 37
# ../archive/Train/25724 37
# ../archive/Train/112339 37
# ../archive/Train/5434 37
# ../archive/Train/95488 37
# ../archive/Train/21384 37
# ../archive/Train/66443 37
# ../archive/Train/88105 37
# ../archive/Train/118603 37
# ../archive/Train/36333 37
# ../archive/Train/79699 37
# ../archive/Train/103845 37
# ../archive/Train/138204 37
# ../archive/Train/22501 37
# ../archive/Train/64314 37
# ../archive/Train/115920 37
# ../archive/Train/61666 37
# ../archive/Train/121329 37
# ../archive/Train/109543 37
# ../archive/Train/27073 37
# ../archive/Train/54581 37
# ../archive/Train/12334 37
# ../archive/Train/54521 37
# ../archive/Train/9259 37
# ../archive/Train/30064 37
# ../archive/Train/16794 37
# ../archive/Train/79639 37
# ../archive/Train/35516 37
# ../archive/Train/73303 37
# ../archive/Train/6211 37
# ../archive/Train/50181 37
# ../archive/Train/67531 37
# ../archive/Train/86803 37
# ../archive/Train/37241 37
# ../archive/Train/112399 37
# ../archive/Train/146875 37
# ../archive/Train/71454 37
# ../archive/Train/4546 37
# ../archive/Train/1034 37
# ../archive/Train/131927 37
# ../archive/Train/10463 37
# ../archive/Train/91088 37
# ../archive/Train/63191 37
# ../archive/Train/68579 37
# ../archive/Train/88999 37
# ../archive/Train/25784 37
# ../archive/Train/56276 37
# ../archive/Train/38807 37
# ../archive/Train/143709 37
# ../archive/Train/21116 37
# ../archive/Train/15323 37
# ../archive/Train/88397 37
# ../archive/Train/45453 37
# ../archive/Train/118491 37
# ../archive/Train/4774 37
# ../archive/Train/57196 37
# ../archive/Train/74314 37
# ../archive/Train/62271 37
# ../archive/Train/42676 37
# ../archive/Train/120069 37
# ../archive/Train/141862 37
# ../archive/Train/139978 37
# ../archive/Train/54713 37
# ../archive/Train/98939 37
# ../archive/Train/51261 37
# ../archive/Train/22793 37
# ../archive/Train/65054 37
# ../archive/Train/64186 37
# ../archive/Train/23641 37
# ../archive/Train/6023 37
# ../archive/Train/59468 37
# ../archive/Train/100836 37
# ../archive/Train/71202 37
# ../archive/Train/4310 37
# ../archive/Train/123288 37
# ../archive/Train/32165 37
# ../archive/Train/74770 37
# ../archive/Train/40545 37
# ../archive/Train/86669 37
# ../archive/Train/48728 37
# ../archive/Train/30632 37
# ../archive/Train/125943 37
# ../archive/Train/60142 37
# ../archive/Train/93189 37
# ../archive/Train/12562 37
# ../archive/Train/108267 37
# ../archive/Train/144148 37
# ../archive/Train/3135 37
# ../archive/Train/133826 37
# ../archive/Train/76027 37
# ../archive/Train/42212 37
# ../archive/Train/23225 37
# ../archive/Train/47760 37
# ../archive/Train/18864 37
# ../archive/Train/35340 37
# ../archive/Train/144974 37
# ../archive/Train/51605 37
# ../archive/Train/65430 37
# ../archive/Train/84902 37
# ../archive/Train/13682 37
# ../archive/Train/54145 37
# ../archive/Train/30400 37
# ../archive/Train/3307 37
# ../archive/Train/42020 37
# ../archive/Train/55097 37
# ../archive/Train/12750 37
# ../archive/Train/73767 37
# ../archive/Train/141608 37
# ../archive/Train/139712 37
# ../archive/Train/17222 37
# ../archive/Train/133228 37
# ../archive/Train/65602 37
# ../archive/Train/104698 37
# ../archive/Train/122954 37
# ../archive/Train/67155 37
# ../archive/Train/100238 37
# ../archive/Train/143963 37
# ../archive/Train/87589 37
# ../archive/Train/33285 37
# ../archive/Train/95870 37
# ../archive/Train/67969 37
# ../archive/Train/122168 37
# ../archive/Train/24232 37
# ../archive/Train/21586 37
# ../archive/Train/52074 37
# ../archive/Train/94358 37
# ../archive/Train/70324 37
# ../archive/Train/44111 37
# ../archive/Train/20454 37
# ../archive/Train/128694 37
# ../archive/Train/41463 37
# ../archive/Train/117049 37
# ../archive/Train/147739 37
# ../archive/Train/69209 37
# ../archive/Train/25126 37
# ../archive/Train/11313 37
# ../archive/Train/57506 37
# ../archive/Train/74784 37
# ../archive/Train/43334 37
# ../archive/Train/132900 37
# ../archive/Train/77101 37
# ../archive/Train/12596 37
# ../archive/Train/98595 37
# ../archive/Train/106309 37
# ../archive/Train/28639 37
# ../archive/Train/47794 37
# ../archive/Train/78149 37
# ../archive/Train/18890 37
# ../archive/Train/124059 37
# ../archive/Train/144980 37
# ../archive/Train/138406 37
# ../archive/Train/27443 37
# ../archive/Train/121719 37
# ../archive/Train/55063 37
# ../archive/Train/61256 37
# ../archive/Train/6681 37
# ../archive/Train/34054 37
# ../archive/Train/50511 37
# ../archive/Train/16304 37
# ../archive/Train/22131 37
# ../archive/Train/7753 37
# ../archive/Train/46474 37
# ../archive/Train/15581 37
# ../archive/Train/14453 37
# ../archive/Train/112709 37
# ../archive/Train/44323 37
# ../archive/Train/143997 37
# ../archive/Train/75464 37
# ../archive/Train/33271 37
# ../archive/Train/38699 37
# ../archive/Train/63501 37
# ../archive/Train/82833 37
# ../archive/Train/31142 37
# ../archive/Train/76685 37
# ../archive/Train/137218 37
# ../archive/Train/61632 37
# ../archive/Train/145638 37
# ../archive/Train/27027 37
# ../archive/Train/99211 37
# ../archive/Train/43562 37
# ../archive/Train/30090 37
# ../archive/Train/2645 37
# ../archive/Train/138250 37
# ../archive/Train/49864 37
# ../archive/Train/34430 37
# ../archive/Train/23487 37
# ../archive/Train/141298 37
# ../archive/Train/115974 37
# ../archive/Train/5460 37
# ../archive/Train/44747 37
# ../archive/Train/63959 37
# ../archive/Train/147953 37
# ../archive/Train/45695 37
# ../archive/Train/57350 37
# ../archive/Train/11545 37
# ../archive/Train/87119 37
# ../archive/Train/75000 37
# ../archive/Train/44575 37
# ../archive/Train/82659 37
# ../archive/Train/39921 37
# ../archive/Train/118465 37
# ../archive/Train/36155 37
# ../archive/Train/57162 37
# ../archive/Train/24490 37
# ../archive/Train/101548 37
# ../archive/Train/104806 37
# ../archive/Train/41007 37
# ../archive/Train/31370 37
# ../archive/Train/97985 37
# ../archive/Train/42682 37
# ../archive/Train/96857 37
# ../archive/Train/2477 37
# ../archive/Train/99023 37
# ../archive/Train/13020 37
# ../archive/Train/51295 37
# ../archive/Train/16552 37
# ../archive/Train/8971 37
# ../archive/Train/113610 37
# ../archive/Train/83116 37
# ../archive/Train/143160 37
# ../archive/Train/131540 37
# ../archive/Train/71833 37
# ../archive/Train/134032 37
# ../archive/Train/4921 37
# ...
# ../archive/Train/71223 37
# ../archive/Train/32978 37
# ../archive/Train/21553 37
# ../archive/Train/116972 37
# ../archive/Train/119106 37
# ../archive/Train/40564 37
# ../archive/Train/74751 37
# ../archive/Train/24021 37
# ../archive/Train/99492 37
# ../archive/Train/18079 37
# ../archive/Train/133807 37
# ../archive/Train/76006 37
# ../archive/Train/26776 37
# ../archive/Train/6466 37
# ../archive/Train/145887 37
# ../archive/Train/17031 37
# ../archive/Train/84923 37
# ../archive/Train/3928 37
# ../archive/Train/93994 37
# ../archive/Train/111965 37
# ../archive/Train/54164 37
# ../archive/Train/27496 37
# ../archive/Train/60351 37
# ../archive/Train/19399 37
# ../archive/Train/98772 37
# ../archive/Train/17203 37
# ../archive/Train/54958 37
# ../archive/Train/7786 37
# ../archive/Train/51416 37
# ../archive/Train/4103 37
# ../archive/Train/134810 37
# ../archive/Train/83108 37
# ../archive/Train/68900 37
# ../archive/Train/122975 37
# ../archive/Train/53341 37
# ../archive/Train/14486 37
# ../archive/Train/32376 37
# ../archive/Train/143942 37
# ../archive/Train/56633 37
# ../archive/Train/100219 37
# ../archive/Train/67948 37
# ../archive/Train/142890 37
# ../archive/Train/95851 37
# ../archive/Train/108410 37
# ../archive/Train/12315 37
# ../archive/Train/98316 37
# ../archive/Train/9278 37
# ../archive/Train/28886 37
# ../archive/Train/79618 37
# ../archive/Train/29168 37
# ../archive/Train/47117 37
# ../archive/Train/53725 37
# ../archive/Train/95409 37
# ../archive/Train/1829 37
# ../archive/Train/71475 37
# ../archive/Train/147986 37
# ../archive/Train/88184 37
# ../archive/Train/146068 37
# ../archive/Train/68558 37
# ../archive/Train/40332 37
# ../archive/Train/131906 37
# ../archive/Train/11590 37
# ../archive/Train/62062 37
# ../archive/Train/53517 37
# ../archive/Train/119562 37
# ../archive/Train/37052 37
# ../archive/Train/56859 37
# ../archive/Train/71647 37
# ../archive/Train/15302 37
# ../archive/Train/63382 37
# ../archive/Train/62250 37
# ../archive/Train/59811 37
# ../archive/Train/76462 37
# ../archive/Train/97950 37
# ../archive/Train/12127 37
# ../archive/Train/30277 37
# ../archive/Train/141843 37
# ../archive/Train/43785 37
# ../archive/Train/65075 37
# ../archive/Train/51240 37
# ../archive/Train/35705 37
# ../archive/Train/98918 37
# ../archive/Train/6002 37
# ../archive/Train/73110 37
# ../archive/Train/139165 37
# ../archive/Train/61613 37
# ../archive/Train/50968 37
# ../archive/Train/115169 37
# ../archive/Train/13233 37
# ../archive/Train/99230 37
# ../archive/Train/46031 37
# ../archive/Train/49845 37
# ../archive/Train/22574 37
# ../archive/Train/16741 37
# ../archive/Train/114887 37
# ../archive/Train/50154 37
# ../archive/Train/34411 37
# ../archive/Train/37294 37
# ../archive/Train/14016 37
# ../archive/Train/118676 37
# ../archive/Train/4593 37
# ../archive/Train/147972 37
# ../archive/Train/83598 37
# ../archive/Train/57371 37
# ../archive/Train/62096 37
# ../archive/Train/127897 37
# ../archive/Train/20011 37
# ../archive/Train/89290 37
# ../archive/Train/118444 37
# ../archive/Train/45486 37
# ../archive/Train/127299 37
# ../archive/Train/39900 37
# ../archive/Train/52431 37
# ../archive/Train/129303 37
# ../archive/Train/33406 37
# ../archive/Train/101569 37
# ../archive/Train/10684 37
# ../archive/Train/36948 37
# ../archive/Train/113890 37
# ../archive/Train/75213 37
# ../archive/Train/76496 37
# ../archive/Train/80913 37
# ../archive/Train/13001 37
# ../archive/Train/27234 37
# ../archive/Train/22746 37
# ../archive/Train/140159 37
# ../archive/Train/8950 37
# ../archive/Train/7124 37
# ../archive/Train/139191 37
# ../archive/Train/132579 37
# ../archive/Train/121952 37
# ../archive/Train/118020 37
# ../archive/Train/88726 37
# ../archive/Train/117854 37
# ../archive/Train/66260 37
# ../archive/Train/116986 37
# ../archive/Train/5217 37
# ../archive/Train/11332 37
# ../archive/Train/25107 37
# ../archive/Train/117068 37
# ../archive/Train/39558 37
# ../archive/Train/129767 37
# ../archive/Train/78954 37
# ../archive/Train/99466 37
# ../archive/Train/13465 37
# ../archive/Train/149 37
# ../archive/Train/109360 37
# ../archive/Train/132921 37
# ../archive/Train/85039 37
# ../archive/Train/124844 37
# ../archive/Train/26782 37
# ../archive/Train/73580 37
# ../archive/Train/975 37
# ../archive/Train/50702 37
# ../archive/Train/64537 37
# ../archive/Train/22322 37
# ../archive/Train/19963 37
# ../archive/Train/93960 37
# ../archive/Train/35395 37
# ../archive/Train/2200 37
# ../archive/Train/77312 37
# ../archive/Train/43127 37
# ../archive/Train/34849 37
# ../archive/Train/99654 37
# ../archive/Train/108080 37
# ../archive/Train/61277 37
# ../archive/Train/103468 37
# ../archive/Train/12785 37
# ../archive/Train/64705 37
# ../archive/Train/125398 37
# ../archive/Train/72660 37
# ../archive/Train/79288 37
# ../archive/Train/138615 37
# ../archive/Train/123853 37
# ../archive/Train/69826 37
# ../archive/Train/88514 37
# ../archive/Train/112728 37
# ../archive/Train/20647 37
# ../archive/Train/142058 37
# ../archive/Train/94977 37
# ../archive/Train/128487 37
# ../archive/Train/41670 37
# ../archive/Train/11100 37
# ../archive/Train/63520 37
# ../archive/Train/126141 37
# ../archive/Train/112374 37
# ../archive/Train/5479 37
# ../archive/Train/62892 37
# ../archive/Train/130024 37
# ../archive/Train/94517 37
# ../archive/Train/68594 37
# ../archive/Train/57349 37
# ../archive/Train/91065 37
# ../archive/Train/134484 37
# ../archive/Train/147176 37
# ../archive/Train/75019 37
# ../archive/Train/51882 37
# ../archive/Train/46835 37
# ../archive/Train/137201 37
# ../archive/Train/19731 37
# ../archive/Train/145621 37
# ../archive/Train/30089 37
# ../archive/Train/50950 37
# ../archive/Train/121364 37
# ../archive/Train/107494 37
# ../archive/Train/31967 37
# ../archive/Train/103808 37
# ../archive/Train/110423 37
# ../archive/Train/27802 37
# ../archive/Train/106546 37
# ../archive/Train/64359 37
# ../archive/Train/19503 37
# ../archive/Train/72832 37
# ../archive/Train/93500 37
# ../archive/Train/7920 37
# ../archive/Train/65885 37
# ../archive/Train/49273 37
# ../archive/Train/9086 37
# ../archive/Train/17499 37
# ../archive/Train/28244 37
# ../archive/Train/99806 37
# ../archive/Train/13805 37
# ../archive/Train/126373 37
# ../archive/Train/112146 37
# ../archive/Train/20029 37
# ../archive/Train/52409 37
# ../archive/Train/94725 37
# ../archive/Train/41822 37
# ../archive/Train/4799 37
# ../archive/Train/146296 37
# ../archive/Train/101551 37
# ../archive/Train/135764 37
# ../archive/Train/87332 37
# ../archive/Train/147344 37
# ../archive/Train/69674 37
# ../archive/Train/132919 37
# ../archive/Train/85001 37
# ../archive/Train/171 37
# ../archive/Train/27668 37
# ../archive/Train/19167 37
# ../archive/Train/55248 37
# ../archive/Train/93164 37
# ../archive/Train/77924 37
# ../archive/Train/18889 37
# ../archive/Train/125192 37
# ../archive/Train/124040 37
# ../archive/Train/93958 37
# ../archive/Train/79082 37
# ../archive/Train/143380 37
# ../archive/Train/36528 37
# ../archive/Train/25903 37
# ../archive/Train/112522 37
# ../archive/Train/142252 37
# ../archive/Train/58557 37
# ../archive/Train/14678 37
# ../archive/Train/33866 37
# ../archive/Train/32188 37
# ../archive/Train/123265 37
# ../archive/Train/69210 37
# ../archive/Train/86684 37
# ../archive/Train/116182 37
# ../archive/Train/15598 37
# ../archive/Train/142060 37
# ../archive/Train/147512 37
# ../archive/Train/117262 37
# ../archive/Train/39752 37
# ../archive/Train/41648 37
# ../archive/Train/33268 37
# ../archive/Train/343 37
# ../archive/Train/121700 37
# ../archive/Train/49425 37
# ../archive/Train/103450 37
# ../archive/Train/54994 37
# ../archive/Train/111195 37
# ../archive/Train/6698 37
# ../archive/Train/96624 37
# ../archive/Train/43923 37
# ../archive/Train/108884 37
# ../archive/Train/55846 37
# ../archive/Train/72658 37
# ../archive/Train/9416 37
# ../archive/Train/78998 37
# ../archive/Train/145083 37
# ../archive/Train/144151 37
# ../archive/Train/124888 37
# ../archive/Train/19193 37
# ../archive/Train/84127 37
# ../archive/Train/125166 37
# ../archive/Train/47779 37
# ../archive/Train/81455 37
# ../archive/Train/80587 37
# ../archive/Train/79076 37
# ../archive/Train/35359 37
# ../archive/Train/107236 37
# ../archive/Train/97530 37
# ../archive/Train/117898 37
# ../archive/Train/59471 37
# ../archive/Train/89638 37
# ../archive/Train/24825 37
# ../archive/Train/95267 37
# ../archive/Train/39594 37
# ../archive/Train/56439 37
# ../archive/Train/90715 37
# ../archive/Train/45812 37
# ../archive/Train/68336 37
# ../archive/Train/122343 37
# ../archive/Train/53977 37
# ../archive/Train/83130 37
# ../archive/Train/21759 37
# ../archive/Train/105753 37
# ../archive/Train/58791 37
# ../archive/Train/53379 37
# ../archive/Train/95055 37
# ../archive/Train/68938 37
# ../archive/Train/10822 37
# ../archive/Train/134014 37
# ../archive/Train/71815 37
# ../archive/Train/100221 37
# ../archive/Train/75489 37
# ../archive/Train/122171 37
# ../archive/Train/116344 37
# ../archive/Train/146434 37
# ../archive/Train/34885 37
# ../archive/Train/136743 37
# ../archive/Train/18273 37
# ../archive/Train/99698 37
# ../archive/Train/102576 37
# ../archive/Train/48503 37
# ../archive/Train/84315 37
# ../archive/Train/107838 37
# ../archive/Train/120626 37
# ../archive/Train/144363 37
# ../archive/Train/35957 37
# ../archive/Train/111161 37
# ../archive/Train/125354 37
# ../archive/Train/141611 37
# ../archive/Train/107004 37
# ../archive/Train/97702 37
# ../archive/Train/131102 37
# ../archive/Train/82486 37
# ../archive/Train/112380 37
# ../archive/Train/119768 37
# ../archive/Train/113252 37
# ../archive/Train/62866 37
# ../archive/Train/83554 37
# ../archive/Train/89852 37
# ../archive/Train/134470 37
# ../archive/Train/88980 37
# ../archive/Train/15934 37
# ../archive/Train/84771 37
# ../archive/Train/114077 37
# ../archive/Train/51876 37
# ../archive/Train/54538 37
# ../archive/Train/136327 37
# ../archive/Train/9240 37
# ../archive/Train/121390 37
# ../archive/Train/97366 37
# ../archive/Train/81203 37
# ../archive/Train/125730 37
# ../archive/Train/141275 37
# ../archive/Train/144535 37
# ../archive/Train/97968 37
# ../archive/Train/114245 37
# ../archive/Train/115397 37
# ../archive/Train/48355 37
# ../archive/Train/107652 37
# ../archive/Train/29362 37
# ../archive/Train/133467 37
# ../archive/Train/141047 37
# ../archive/Train/106780 37
# ../archive/Train/73128 37
# ../archive/Train/111737 37
# ../archive/Train/136929 37
# ../archive/Train/125502 37
# ../archive/Train/81031 37
# ../archive/Train/40904 37
# ../archive/Train/131330 37
# ../archive/Train/143710 37
# ../archive/Train/56861 37
# ../archive/Train/118488 37
# ../archive/Train/83766 37
# ../archive/Train/127255 37
# ../archive/Train/40138 37
# ../archive/Train/105939 37
# ../archive/Train/32518 37
# ../archive/Train/90371 37
# ../archive/Train/100477 37
# ../archive/Train/62268 37
# ../archive/Train/109155 37
# ../archive/Train/136788 37
# ../archive/Train/13650 37
# ../archive/Train/43120 37
# ../archive/Train/55045 37
# ../archive/Train/98781 37
# ../archive/Train/61270 37
# ../archive/Train/34072 37
# ../archive/Train/138612 37
# ../archive/Train/140708 37
# ../archive/Train/55879 37
# ../archive/Train/7775 37
# ../archive/Train/46452 37
# ../archive/Train/88513 37
# ../archive/Train/123854 37
# ../archive/Train/14475 37
# ../archive/Train/135931 37
# ../archive/Train/82029 37
# ../archive/Train/25332 37
# ../archive/Train/123068 37
# ../archive/Train/75442 37
# ../archive/Train/1482 37
# ../archive/Train/74590 37
# ../archive/Train/142863 37
# ../archive/Train/57712 37
# ../archive/Train/63527 37
# ../archive/Train/101338 37
# ../archive/Train/15795 37
# ../archive/Train/36517 37
# ../archive/Train/70302 37
# ../archive/Train/5210 37
# ../archive/Train/58568 37
# ../archive/Train/33859 37
# ../archive/Train/41445 37
# ../archive/Train/75670 37
# ../archive/Train/57520 37
# ../archive/Train/33065 37
# ../archive/Train/129760 37
# ../archive/Train/43312 37
# ../archive/Train/132926 37
# ../archive/Train/145048 37
# ../archive/Train/109367 37
# ../archive/Train/27657 37
# ../archive/Train/92089 37
# ../archive/Train/78953 37
# ../archive/Train/55277 37
# ../archive/Train/26785 37
# ../archive/Train/49628 37
# ../archive/Train/85802 37
# ../archive/Train/50705 37
# ../archive/Train/73587 37
# ../archive/Train/6495 37
# ../archive/Train/46660 37
# ../archive/Train/138420 37
# ../archive/Train/112179 37
# ../archive/Train/119591 37
# ../archive/Train/89297 37
# ../archive/Train/20016 37
# ../archive/Train/39907 37
# ../archive/Train/88345 37
# ../archive/Train/36173 37
# ../archive/Train/57144 37
# ../archive/Train/112945 37
# ../archive/Train/33401 37
# ../archive/Train/58930 37
# ../archive/Train/25564 37
# ../archive/Train/134689 37
# ../archive/Train/11751 37
# ../archive/Train/103239 37
# ../archive/Train/31356 37
# ../archive/Train/43776 37
# ../archive/Train/64968 37
# ../archive/Train/2451 37
# ../archive/Train/77543 37
# ../archive/Train/96871 37
# ../archive/Train/30284 37
# ../archive/Train/109703 37
# ../archive/Train/27233 37
# ../archive/Train/46204 37
# ../archive/Train/138044 37
# ../archive/Train/107699 37
# ../archive/Train/120887 37
# ../archive/Train/65086 37
# ../archive/Train/23693 37
# ../archive/Train/64154 37
# ../archive/Train/121955 37
# ../archive/Train/9885 37
# ../archive/Train/99839 37
# ../archive/Train/8359 37
# ../archive/Train/42496 37
# ../archive/Train/55421 37
# ../archive/Train/27001 37
# ../archive/Train/718 37
# ../archive/Train/13234 37
# ../archive/Train/85668 37
# ../archive/Train/2663 37
# ../archive/Train/77771 37
# ../archive/Train/49842 37
# ../archive/Train/46036 37
# ../archive/Train/14011 37
# ../archive/Train/70554 37
# ../archive/Train/5446 37
# ../archive/Train/71486 37
# ../archive/Train/36341 37
# ../archive/Train/66431 37
# ../archive/Train/52604 37
# ../archive/Train/57376 37
# ../archive/Train/63143 37
# ../archive/Train/24684 37
# ../archive/Train/25756 37
# ../archive/Train/62091 37
# ../archive/Train/117639 37
# ../archive/Train/53510 37
# ../archive/Train/83759 37
# ../archive/Train/4752 37
# ../archive/Train/71640 37
# ../archive/Train/74332 37
# ../archive/Train/105906 37
# ../archive/Train/59816 37
# ../archive/Train/25590 37
# ../archive/Train/56062 37
# ../archive/Train/108625 37
# ../archive/Train/26315 37
# ../archive/Train/30270 37
# ../archive/Train/96885 37
# ../archive/Train/60500 37
# ../archive/Train/6839 37
# ../archive/Train/92419 37
# ../archive/Train/35702 37
# ../archive/Train/16580 37
# ../archive/Train/65072 37
# ../archive/Train/120873 37
# ../archive/Train/141078 37
# ../archive/Train/139162 37
# ../archive/Train/17452 37
# ../archive/Train/111708 37
# ../archive/Train/136916 37
# ../archive/Train/114048 37
# ../archive/Train/51849 37
# ../archive/Train/76657 37
# ../archive/Train/31190 37
# ../archive/Train/42462 37
# ../archive/Train/108417 37
# ../archive/Train/144738 37
# ../archive/Train/18628 37
# ../archive/Train/28881 37
# ../archive/Train/2697 37
# ../archive/Train/51075 37
# ../archive/Train/97359 37
# ../archive/Train/140398 37
# ../archive/Train/65240 37
# ../archive/Train/35530 37
# ../archive/Train/102911 37
# ../archive/Train/73325 37
# ../archive/Train/64392 37
# ../archive/Train/17660 37
# ../archive/Train/67517 37
# ../archive/Train/37267 37
# ../archive/Train/127058 37
# ../archive/Train/118685 37
# ../archive/Train/71472 37
# ../archive/Train/90940 37
# ../archive/Train/21302 37
# ../archive/Train/15137 37
# ../archive/Train/131901 37
# ../archive/Train/86019 37
# ../archive/Train/127864 37
# ../archive/Train/56250 37
# ../archive/Train/128010 37
# ../archive/Train/60356 37
# ../archive/Train/111962 37
# ../archive/Train/30426 37
# ../archive/Train/76233 37
# ../archive/Train/47574 37
# ../archive/Train/81658 37
# ../archive/Train/6653 37
# ../archive/Train/73741 37
# ../archive/Train/51411 37
# ../archive/Train/65624 37
# ../archive/Train/4104 37
# ../archive/Train/143179 37
# ../archive/Train/52294 37
# ../archive/Train/131559 37
# ../archive/Train/14481 37
# ../archive/Train/62401 37
# ../archive/Train/83933 37
# ../archive/Train/128474 37
# ../archive/Train/39799 37
# ../archive/Train/95856 37
# ../archive/Train/1476 37
# ../archive/Train/24214 37
# ../archive/Train/66293 37
# ../archive/Train/71224 37
# ../archive/Train/37431 37
# ../archive/Train/89607 37
# ../archive/Train/95258 37
# ../archive/Train/116975 37
# ../archive/Train/32143 37
# ../archive/Train/134219 37
# ../archive/Train/24026 37
# ../archive/Train/146639 37
# ../archive/Train/38479 37
# ../archive/Train/53948 37
# ../archive/Train/74756 37
# ../archive/Train/1644 37
# ../archive/Train/129794 37
# ../archive/Train/30614 37
# ../archive/Train/60164 37
# ../archive/Train/13496 37
# ../archive/Train/55283 37
# ../archive/Train/108241 37
# ../archive/Train/26771 37
# ../archive/Train/133800 37
# ../archive/Train/3113 37
# ../archive/Train/42234 37
# ../archive/Train/125159 37
# ../archive/Train/60958 37
# ../archive/Train/6461 37
# ../archive/Train/73573 37
# ../archive/Train/93993 37
# ../archive/Train/46694 37
# ../archive/Train/144952 37

# %%
import pandas as pd

# Assuming main_path is the main directory where all videos are stored
# and df contains columns 'video_id' and 'label'
def create_video_path_df(df, main_path):
    # Create a new column 'video_path' by combining main_path with video_id
    df['video_path'] = main_path + "/"+ df['video_id'].astype(str)  # Assuming video_id is integer

    # Return a DataFrame containing video_id, video_path, and label columns
    return df[['video_id', 'video_path', 'label']]


#application
main_path = "/Users/mac/Documents/2CS_IASD/S2/PROJET_2CS/Sprint1_arsl/Jester_classification/archive/Train"
video_path_df = create_video_path_df(df_train, main_path)
print(video_path_df['video_path'].iloc[2])
# Out:
# /Users/mac/Documents/2CS_IASD/S2/PROJET_2CS/Sprint1_arsl/Jester_classification/archive/Train/6

# %%
def build_feature_extractor():
    feature_extractor = DenseNet121(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )
    preprocess_input = keras.applications.densenet.preprocess_input

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return keras.Model(inputs, outputs, name="feature_extractor")


feature_extractor = build_feature_extractor()


# Label preprocessing with StringLookup.
label_processor = keras.layers.StringLookup(
    num_oov_indices=0, vocabulary=np.unique(df_train["label"]), mask_token=None
)
print(label_processor.get_vocabulary())

center_crop_layer = layers.CenterCrop(IMG_SIZE, IMG_SIZE)


def crop_center(frame):
    cropped = center_crop_layer(frame[None, ...])
    cropped = keras.ops.convert_to_numpy(cropped)
    cropped = keras.ops.squeeze(cropped)
    return cropped


def load_video(path, max_frames=0, offload_to_cpu=False):
    cap = cv2.VideoCapture(path)
    frames = []
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = frame[:, :, [2, 1, 0]]
            frame = crop_center(frame)
            if offload_to_cpu and keras.backend.backend() == "torch":
                frame = frame.to("cpu")
            frames.append(frame)

            if len(frames) == max_frames:
                break
    finally:
        cap.release()
    if offload_to_cpu and keras.backend.backend() == "torch":
        return np.array([frame.to("cpu").numpy() for frame in frames])
    return np.array(frames)

# %%
import os
from PIL import Image
import numpy as np

from PIL import Image
import numpy as np

def load_frame(frame_path, target_size=(128, 128)):
    # Open the image file using PIL (Python Imaging Library)
    img = Image.open(frame_path)
    # Resize the image to the target size
    img_resized = img.resize(target_size)
    # Convert the resized image to a NumPy array and normalize pixel values to the range [0, 1]
    img_array = np.array(img_resized) / 255.0
    return img_array


def prepare_all_videos(df, root_dir):
    num_samples = len(df)
    video_paths = df["video_path"].values.tolist()
    labels = df["label"].values
    labels = label_processor(labels[..., None]).numpy()

    # `frame_features` are what we will feed to our sequence model.
    frame_features = np.zeros(
        shape=(num_samples, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
    )

    # For each video path.
    for idx, path in enumerate(video_paths):
        frames = []

        # Iterate over frames in the video folder.
        for frame_name in os.listdir(os.path.join(root_dir, path)):
            frame_path = os.path.join(root_dir, path, frame_name)
            frame = load_frame(frame_path)  # Load the frame (modify this function according to your needs)
            frames.append(frame)

            if len(frames) == MAX_SEQ_LENGTH:
                break  # Stop iterating if we've reached the maximum sequence length

        # Pad shorter sequences.
        if len(frames) < MAX_SEQ_LENGTH:
            diff = MAX_SEQ_LENGTH - len(frames)
            padding = np.zeros((diff, IMG_SIZE, IMG_SIZE, 3))
            frames.extend(padding)

        # Initialize placeholder to store the features of the current video.
        temp_frame_features = np.zeros(
            shape=(1, MAX_SEQ_LENGTH, NUM_FEATURES), dtype="float32"
        )

        # Extract features from the frames.
        for i, frame in enumerate(frames):
            if np.mean(frame) > 0.0:
                temp_frame_features[0, i, :] = feature_extractor.predict(
                    frame[None, ...]
                )
            else:
                temp_frame_features[0, i, :] = 0.0

        frame_features[idx] = temp_frame_features.squeeze()

   

    return frame_features, labels

# %%
frame_feature, labels= prepare_all_videos(video_path_df[:300],"/Users/mac/Documents/2CS_IASD/S2/PROJET_2CS/Sprint1_arsl/Jester_classification/archive/Train")

# %%
print(frame_feature)

# %%
# Reshape the 3D array into 2D
reshaped_array = frame_feature.reshape(frame_feature.shape[0], -1)

# Save the reshaped array to a text file
np.savetxt('./preprocessed/features.txt', reshaped_array)
